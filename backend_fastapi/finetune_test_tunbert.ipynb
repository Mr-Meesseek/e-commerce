# %%
# !git clone https://github.com/instadeepai/tunbert
# !git clone https://github.com/RouaMokni/tunbert temp
# !mv temp/models/bert-google/bert/predict.py tunbert/models/bert-google/bert/predict.py
# !rm -rf temp
# Out:
# Cloning into 'tunbert'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 88 (delta 26), reused 77 (delta 19), pack-reused 0
# Receiving objects: 100% (88/88), 160.93 KiB | 3.42 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# Cloning into 'temp'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (9/9), 12.76 KiB | 1.82 MiB/s, done.

# %%
# %cd /content/tunbert/
# !mkdir tf_tunbert
# %cd /content/tunbert/tf_tunbert
# !wget https://storage.googleapis.com/ext-oss-tunbert-gcp/TensorFlow_model/bert_config.json
# !wget https://storage.googleapis.com/ext-oss-tunbert-gcp/TensorFlow_model/vocab.txt
# !wget https://storage.googleapis.com/ext-oss-tunbert-gcp/TensorFlow_model/bert_model_step_616000.ckpt-154.data-00000-of-00001.index
# !wget https://storage.googleapis.com/ext-oss-tunbert-gcp/TensorFlow_model/bert_model_step_616000.ckpt-154.data-00000-of-00001
# Out:
# /content/tunbert
# /content/tunbert/tf_tunbert
# --2024-05-18 12:36:14--  https://storage.googleapis.com/ext-oss-tunbert-gcp/TensorFlow_model/bert_config.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.162.207, 74.125.134.207, 74.125.139.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.162.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 503 [application/json]
# Saving to: ‘bert_config.json’
#
# bert_config.json    100%[===================>]     503  --.-KB/s    in 0s
#
# 2024-05-18 12:36:14 (237 MB/s) - ‘bert_config.json’ saved [503/503]
#
# --2024-05-18 12:36:14--  https://storage.googleapis.com/ext-oss-tunbert-gcp/TensorFlow_model/vocab.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.162.207, 74.125.134.207, 74.125.139.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.162.207|:443... connected.
# ...

# %%
# !ls
# Out:
# bert_config.json
# bert_model_step_616000.ckpt-154.data-00000-of-00001
# bert_model_step_616000.ckpt-154.data-00000-of-00001.index
# vocab.txt

# %%
# !pip install transformers

# %%
from transformers import BertTokenizer, TFBertModel

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# ...

# %%
# !ls
# Out:
# bert_config.json
# bert_model_step_616000.ckpt-154.data-00000-of-00001
# bert_model_step_616000.ckpt-154.data-00000-of-00001.index
# vocab.txt

# %%
# %pwd
# Out:
# '/content/tunbert/tf_tunbert'

# %%
# !pip install pre-commit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 45.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 32.4 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade click black
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.3 MB/s eta 0:00:00
# ...

# %%
# !pre-commit run --all-files
# Out:
# [INFO] Initializing environment for https://github.com/asottile/seed-isort-config.
# [INFO] Initializing environment for https://github.com/pre-commit/mirrors-isort.
# [INFO] Initializing environment for https://github.com/python/black.
# [INFO] Initializing environment for https://gitlab.com/pycqa/flake8.
# An unexpected error has occurred: CalledProcessError: command: ('/usr/bin/git', 'fetch', 'origin', '--tags')
# return code: 128
# stdout: (none)
# stderr:
#     fatal: could not read Username for 'https://gitlab.com': No such device or address
# Check the log at /root/.cache/pre-commit/pre-commit.log

# %%
# !black --version
# Out:
# black, 24.4.2 (compiled: yes)
# Python (CPython) 3.10.12

# %%
# !chmod +x /content/tunbert/models/bert-google/finetuning_squad.sh

# %%
# %cd /content/tunbert/
# !mkdir -p finetuning_trcd
# Out:
# /content/tunbert

# %%
# %cd /content/tunbert/
# !python /content/tunbert/models/bert-google/bert/run_squad.py \
  --vocab_file=/content/tunbert/tf_tunbert/vocab.txt \
  --bert_config_file=/content/tunbert/tf_tunbert/bert_config.json \
  --init_checkpoint=/content/tunbert/tf_tunbert/bert_model_step_616000.ckpt-154.data-00000-of-00001 \
  --do_train=True \
  --train_file=/content/tunbert/dev-data/question_answering_trcd/train.json \
  --do_predict=True \
  --predict_file=/content/tunbert/dev-data/question_answering_trcd/test.json \
  --train_batch_size=2 \
  --learning_rate=3e-5 \
  --num_train_epochs=5 \
  --max_seq_length=384 \
  --doc_stride=128 \
  --do_lower_case=False \
  --output_dir=/content/tunbert/finetuning_trcd/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# INFO:tensorflow:examples/sec: 8.76719
# I0518 12:40:15.552134 134823403945984 tpu_estimator.py:2392] examples/sec: 8.76719
# INFO:tensorflow:global_step/sec: 4.38856
# I0518 12:40:15.779537 134823403945984 tpu_estimator.py:2391] global_step/sec: 4.38856
# INFO:tensorflow:examples/sec: 8.77713
# I0518 12:40:15.779818 134823403945984 tpu_estimator.py:2392] examples/sec: 8.77713
# INFO:tensorflow:global_step/sec: 4.40874
# I0518 12:40:16.006350 134823403945984 tpu_estimator.py:2391] global_step/sec: 4.40874
# INFO:tensorflow:examples/sec: 8.81747
# I0518 12:40:16.006757 134823403945984 tpu_estimator.py:2392] examples/sec: 8.81747
# INFO:tensorflow:global_step/sec: 4.37124
# I0518 12:40:16.235137 134823403945984 tpu_estimator.py:2391] global_step/sec: 4.37124
# INFO:tensorflow:examples/sec: 8.74248
# I0518 12:40:16.235516 134823403945984 tpu_estimator.py:2392] examples/sec: 8.74248
# ...

# %%
# !python /content/tunbert/models/bert-google/bert/evaluate.py \
  --dataset_file=/content/tunbert/dev-data/question_answering_trcd/test.json \
  --prediction_file=/content/tunbert/finetuning_trcd/predictions.json
# Out:
# {"exact_match": 3.125, "f1": 24.603890129463018, "recall": 28.62081559766782}

# %% [markdown]
# **Télécharger le fichier "predict.py"**

# %%
#%cd /content/tunbert/models/bert-google/bert/
#!wget "https://drive.usercontent.google.com/download?id=1E7qPvOaSlPMiecYVCSiFwEz0GeKIROMB&export=download&authuser=0&confirm=t&uuid=86bcdfc0-492c-4575-b3f7-f67b0d48a833&at=APZUnTV4B9awuLwtbanczKAJdYRE:1709576461453" -O predict.py

# %%
# !ls /content/tunbert/finetuning_trcd/
# Out:
# checkpoint				     model.ckpt-1000.index
# eval.tf_record				     model.ckpt-1000.meta
# events.out.tfevents.1716035958.609affdc575f  model.ckpt-1140.data-00000-of-00001
# graph.pbtxt				     model.ckpt-1140.index
# model.ckpt-0.data-00000-of-00001	     model.ckpt-1140.meta
# model.ckpt-0.index			     nbest_predictions.json
# model.ckpt-0.meta			     predictions.json
# model.ckpt-1000.data-00000-of-00001	     train.tf_record
